# %%
import pandas as pd
import matplotlib.pyplot as plt
import plotly.graph_objects as go
import mplfinance as mpf

data = pd.read_csv('AAVEUSDT2022-07-10.csv')
data = data.drop(['tickDirection', 'trdMatchID'], axis=1)
data['timestamp'] = pd.to_datetime(data['timestamp'], unit='s')
data.head()
# Out:
#             timestamp    symbol side   size  price    grossValue  \
# 0 2022-07-10 00:00:12  AAVEUSDT  Buy   7.00   81.8  5.726000e+10
# 1 2022-07-10 00:00:20  AAVEUSDT  Buy  35.20   81.8  2.879360e+11
# 2 2022-07-10 00:00:20  AAVEUSDT  Buy   7.00   81.8  5.726000e+10
# 3 2022-07-10 00:00:20  AAVEUSDT  Buy   9.79   81.8  8.008220e+10
# 4 2022-07-10 00:00:20  AAVEUSDT  Buy   9.79   81.8  8.008220e+10
#
#    homeNotional  foreignNotional
# 0          7.00          572.600
# 1         35.20         2879.360
# 2          7.00          572.600
# 3          9.79          800.822
# 4          9.79          800.822

# %%
filter = (data['timestamp'] >= '2022-07-10 00:30:00') & (data['timestamp'] <= '2022-07-10 00:31:00')
data.loc[filter]

# %%
minutly_price = data.groupby([pd.Grouper(
    key='timestamp', freq='min')]).agg(
        Open = ('price', 'first'),
        High = ('price', 'max'),
        Low = ('price', 'min'),
        Close = ('price', 'last'),
        Volume = ('size', 'sum'), ).round(2)
minutly_price.head()
# Out:
#                       Open   High    Low  Close   Volume
# timestamp
# 2022-07-10 00:00:00  81.80  81.95  81.80  81.80   430.50
# 2022-07-10 00:01:00  81.85  82.10  81.80  82.00  1642.93
# 2022-07-10 00:02:00  82.05  82.10  81.85  81.95   249.23
# 2022-07-10 00:03:00  82.00  82.05  81.95  82.00    78.82
# 2022-07-10 00:04:00  82.00  82.00  81.80  81.85   631.03

# %%
minutly_price.columns.tolist()
# Out:
# ['Open', 'High', 'Low', 'Close', 'Volume']

# %%
mpf.plot(minutly_price,style='yahoo', type='candle', volume=True)

# %%
minutly_price.rename(columns = {'timestamp' : 'Timestamp'}, inplace = True)

minutly_price.head()
#minutly_price.reset_index()
# Out:
#             Timestamp   Open   High    Low  Close   Volume
# 0 2022-07-10 00:00:00  81.80  81.95  81.80  81.80   430.50
# 1 2022-07-10 00:01:00  81.85  82.10  81.80  82.00  1642.93
# 2 2022-07-10 00:02:00  82.05  82.10  81.85  81.95   249.23
# 3 2022-07-10 00:03:00  82.00  82.05  81.95  82.00    78.82
# 4 2022-07-10 00:04:00  82.00  82.00  81.80  81.85   631.03

# %%
fig = go.Figure(data=[go.Candlestick(
                x=minutly_price.index.to_list(),
                open=minutly_price['Open'],
                high=minutly_price['High'],
                low=minutly_price['Low'],
                close=minutly_price['Close'])])

fig.show()

# %%
hourly_price = data.groupby([pd.Grouper(
    key='timestamp', freq='H')]).agg(
        High = ('price', 'max'),
        Low = ('price', 'min'),
        Open = ('price', 'first'),
        Close = ('price', 'last'),
        Volume = ('size', 'sum'), ).round(2)
hourly_price.head(24)
# Out:
#                       High    Low   Open  Close     Volume
# timestamp
# 2022-07-10 00:00:00  82.10  79.45  81.80  79.60   43072.77
# 2022-07-10 01:00:00  80.70  78.55  79.65  78.65   43319.46
# 2022-07-10 02:00:00  79.45  77.15  78.65  78.85   31518.30
# 2022-07-10 03:00:00  78.90  77.45  78.80  77.85   23232.52
# 2022-07-10 04:00:00  79.25  77.35  77.80  78.90   26194.27
# 2022-07-10 05:00:00  79.00  78.05  78.85  78.70   15846.35
# 2022-07-10 06:00:00  79.15  78.15  78.70  78.60   10415.79
# 2022-07-10 07:00:00  81.10  78.40  78.60  80.25   33342.11
# 2022-07-10 08:00:00  81.55  80.05  80.20  80.50   29152.15
# 2022-07-10 09:00:00  80.75  79.15  80.45  79.80   23817.10
# 2022-07-10 10:00:00  81.10  79.35  79.80  79.95   21498.45
# 2022-07-10 11:00:00  81.05  79.35  80.00  80.45   34513.33
# 2022-07-10 12:00:00  82.20  80.30  80.50  81.70   33929.38
# 2022-07-10 13:00:00  82.00  79.55  81.75  80.15   49084.78
# 2022-07-10 14:00:00  80.15  76.10  80.10  76.60  111123.73
# 2022-07-10 15:00:00  77.30  75.25  76.55  75.70   38116.92
# 2022-07-10 16:00:00  76.85  74.75  75.70  76.45   44543.23
# 2022-07-10 17:00:00  77.80  76.15  76.45  77.80   32548.97
# 2022-07-10 18:00:00  77.90  76.55  77.80  77.40   18588.40
# 2022-07-10 19:00:00  77.50  76.10  77.40  77.40   25422.16
# 2022-07-10 20:00:00  77.50  76.55  77.35  77.00   18230.37
# 2022-07-10 21:00:00  78.10  76.60  77.05  76.65   15778.67
# 2022-07-10 22:00:00  76.70  75.25  76.60  76.40   20405.30
# 2022-07-10 23:00:00  78.40  75.95  76.45  77.70   21518.34

# %%
mpf.plot(hourly_price,style='yahoo', type='candle', volume=True)

# %%
plt.plot(data.timestamp, data.price)

# %%
data.sort_values(by = ["timestamp", "price"])
# Out:
#                 timestamp    symbol side   size  price    grossValue  \
# 0     2022-07-10 00:00:12  AAVEUSDT  Buy   7.00  81.80  5.726000e+10
# 1     2022-07-10 00:00:20  AAVEUSDT  Buy  35.20  81.80  2.879360e+11
# 2     2022-07-10 00:00:20  AAVEUSDT  Buy   7.00  81.80  5.726000e+10
# 3     2022-07-10 00:00:20  AAVEUSDT  Buy   9.79  81.80  8.008220e+10
# 4     2022-07-10 00:00:20  AAVEUSDT  Buy   9.79  81.80  8.008220e+10
# ...                   ...       ...  ...    ...    ...           ...
# 60003 2022-07-10 23:59:57  AAVEUSDT  Buy   1.30  77.65  1.009450e+10
# 60004 2022-07-10 23:59:57  AAVEUSDT  Buy   1.30  77.65  1.009450e+10
# 60005 2022-07-10 23:59:57  AAVEUSDT  Buy  26.52  77.65  2.059278e+11
# 60006 2022-07-10 23:59:57  AAVEUSDT  Buy   1.30  77.70  1.010100e+10
# 60007 2022-07-10 23:59:57  AAVEUSDT  Buy   0.01  77.70  7.770000e+07
#
#        homeNotional  foreignNotional
# 0              7.00          572.600
# 1             35.20         2879.360
# 2              7.00          572.600
# 3              9.79          800.822
# 4              9.79          800.822
# ...             ...              ...
# 60003          1.30          100.945
# 60004          1.30          100.945
# 60005         26.52         2059.278
# 60006          1.30          101.010
# 60007          0.01            0.777
#
# [60008 rows x 8 columns]
